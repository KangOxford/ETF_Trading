# %%
import requests
from bs4 import BeautifulSoup

# %%
target = "http://www.sse.com.cn/disclosure/fund/etflist/"
response = requests.get(url = target)
html_text = response.text.encode('iso-8859-1').decode('utf-8')
print(html_text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# 	<meta charset="utf-8">
# 	<title>ETF公告申购赎回清单  |  上海证券交易所</title>
# 	<meta name="description" content="">
# 	<meta name="author" content="上海证券交易所">
# 	<meta name="renderer" content="webkit">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# 	<meta name="apple-mobile-web-app-capable" content="yes">
# 	<meta name="mobile-web-app-capable" content="yes">
# 	<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0">
# 	<meta name="apple-mobile-web-app-title" content="上海证券交易所">
#
#             <script>var col_id=8363 ; var col_old_id="http://www.sse.com.cn/disclosure/diclosure/etf/";  </script>
#
#
# 	<!-- CSS -->
#     <link href="http://www.sse.com.cn/css/sse_allcss.min.css;wa208abf441447c8db" rel="stylesheet" type="text/css" charset="utf-8" >
# <link href="http://www.sse.com.cn/css/sse_allcss2.min.css;wa7cf1422047e5f3e2" rel="stylesheet" type="text/css" charset="utf-8" >
# ...

# %%
html_contents = reques

# %%
soup = BeautifulSoup(html_text)
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>ETF公告申购赎回清单  |  上海证券交易所</title>
# <meta content="" name="description"/>
# <meta content="上海证券交易所" name="author"/>
# <meta content="webkit" name="renderer"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport"/>
# <meta content="上海证券交易所" name="apple-mobile-web-app-title"/>
# <script>var col_id=8363 ; var col_old_id="http://www.sse.com.cn/disclosure/diclosure/etf/";  </script>
# <!-- CSS -->
# <link charset="utf-8" href="http://www.sse.com.cn/css/sse_allcss.min.css;wa208abf441447c8db" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="http://www.sse.com.cn/css/sse_allcss2.min.css;wa7cf1422047e5f3e2" rel="stylesheet" type="text/css"/>
# ...
